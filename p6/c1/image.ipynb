# %%
from PIL import Image

img = Image.open("simba.png")

img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=250x263>

# %%
w, h = img.size
print(f'simba fait {w} pixel de largeur et {h} pixel de hauteur')
# Out:
# simba fait 250 pixel de largeur et 263 pixel de hauteur

# %%
import numpy as np

mat = np.array(img)
mat
# Out:
# array([[247, 245, 245, ..., 224, 228, 228],
#        [246, 244, 243, ..., 228, 230, 230],
#        [244, 242, 240, ..., 230, 231, 231],
#        ...,
#        [183, 169, 169, ..., 108,  95, 102],
#        [170, 160, 171, ...,  81,  95,  99],
#        [150, 155, 174, ..., 133, 115, 111]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

plt.hist(mat.flatten(), bins=range(256))
plt.show()

# %%
from PIL import ImageColor

img = ImageColor.
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[23], line 4
#       1 from PIL import ImageOps
#       3 img = Image.open('simba_surexp.png')
# ----> 4 img = ImageOps.autocontrast(img)
#       5 img
#
# File ~\anaconda3\envs\projet6\lib\site-packages\PIL\ImageOps.py:155, in autocontrast(image, cutoff, ignore, mask, preserve_tone)
#     153                 ix = 255
#     154             lut.append(ix)
# --> 155 return _lut(image, lut)
#
# File ~\anaconda3\envs\projet6\lib\site-packages\PIL\ImageOps.py:60, in _lut(image, lut)
#      58 else:
#      59     msg = "not supported for this image mode"
# ---> 60     raise OSError(msg)
#
# OSError: not supported for this image mode

# %%
mat = np.array(img)
plt.hist(mat.flatten(), bins=range(256))
plt.show()

# %%
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=100, noise=0.25)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
from sklearn.ensemble import BaggingClassifier 

bagging = BaggingClassifier(n_estimators=5)
bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier(n_estimators=5)

# %%
! pip install mglearn
# Out:
# Collecting mglearn
#   Using cached mglearn-0.2.0-py2.py3-none-any.whl (581 kB)
# Requirement already satisfied: numpy in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from mglearn) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from mglearn) (3.7.1)
# Requirement already satisfied: scikit-learn in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from mglearn) (1.2.2)
# Requirement already satisfied: pandas in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from mglearn) (2.0.1)
# Requirement already satisfied: pillow in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from mglearn) (9.5.0)
# Requirement already satisfied: cycler in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from mglearn) (0.11.0)
# Collecting imageio (from mglearn)
#   Using cached imageio-2.31.0-py3-none-any.whl (313 kB)
# Requirement already satisfied: joblib in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from mglearn) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from matplotlib->mglearn) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from matplotlib->mglearn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from matplotlib->mglearn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from matplotlib->mglearn) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from matplotlib->mglearn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from matplotlib->mglearn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from matplotlib->mglearn) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from pandas->mglearn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from pandas->mglearn) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from scikit-learn->mglearn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from scikit-learn->mglearn) (3.1.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->mglearn) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\papoun\anaconda3\envs\oc-p4b\lib\site-packages (from python-dateutil>=2.7->matplotlib->mglearn) (1.16.0)
# Installing collected packages: imageio, mglearn
# Successfully installed imageio-2.31.0 mglearn-0.2.0

# %%
import matplotlib.pyplot as plt
from mglearn.plot_interactive_tree import plot_tree_partition
from mglearn.plot_2d_separator import plot_2d_separator
from mglearn.tools import discrete_scatter

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 10))
for i, (ax, tree) in enumerate(zip(axes.ravel(), bagging.estimators_)):
    ax.set_title("Tree {}".format(i))
    plot_tree_partition(X_train, y_train, tree, ax=ax)
plot_2d_separator(bagging, X_train, fill=True, ax=axes[-1, -1],
                                    alpha=.4)
axes[-1, -1].set_title("Bagging")
discrete_scatter(X_train[:, 0], X_train[:, 1], y_train)
# Out:
# [<matplotlib.lines.Line2D at 0x2315328e4f0>,
#  <matplotlib.lines.Line2D at 0x2315230c100>]

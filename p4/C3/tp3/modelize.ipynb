# %%
import pandas as pd

# %%
raw_data = pd.read_csv('data/ecg.csv', sep=',', header=None)
raw_data.head()
# Out:
#         0         1         2         3    ...       137       138       139  140
# 0 -0.112522 -2.827204 -3.773897 -4.349751  ...  0.123431  0.925286  0.193137  1.0
# 1 -1.100878 -3.996840 -4.285843 -4.506579  ...  0.773820  1.119621 -1.436250  1.0
# 2 -0.567088 -2.593450 -3.874230 -4.584095  ...  0.321097  0.904227 -0.421797  1.0
# 3  0.490473 -1.914407 -3.616364 -4.318823  ...  1.086798  1.403011 -0.383564  1.0
# 4  0.800232 -0.874252 -2.384761 -3.973292  ...  0.971020  1.614392  1.421456  1.0
#
# [5 rows x 141 columns]

# %%
X = raw_data.iloc[:, :-1]
y = raw_data[140]

# %%
from sklearn import model_selection
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
model = models.Sequential()
model.add(keras.Input(shape=X.shape[1]))
model.add(layers.Dense(X.shape[1], activation='sigmoid', input_dim=2))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(metrics=['accuracy'], loss='binary_crossentropy', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 140)               19740
#
#  dense_3 (Dense)             (None, 1)                 141
#
# =================================================================
# Total params: 19,881
# Trainable params: 19,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=50, batch_size=4, verbose=1)
# Out:
# Epoch 1/50
# 875/875 [==============================] - 4s 3ms/step - loss: 0.0769 - accuracy: 0.9783
# Epoch 2/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0375 - accuracy: 0.9917
# Epoch 3/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0311 - accuracy: 0.9903
# Epoch 4/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0284 - accuracy: 0.9903
# Epoch 5/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0244 - accuracy: 0.9923
# Epoch 6/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0231 - accuracy: 0.9934
# Epoch 7/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0225 - accuracy: 0.9946
# Epoch 8/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0198 - accuracy: 0.9949
# Epoch 9/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0189 - accuracy: 0.9940
# Epoch 10/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0176 - accuracy: 0.9954
# Epoch 11/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0153 - accuracy: 0.9960
# Epoch 12/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0155 - accuracy: 0.9951
# Epoch 13/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0137 - accuracy: 0.9971
# Epoch 14/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0135 - accuracy: 0.9969
# Epoch 15/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0111 - accuracy: 0.9977
# Epoch 16/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0116 - accuracy: 0.9969
# Epoch 17/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0101 - accuracy: 0.9974
# Epoch 18/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0093 - accuracy: 0.9977
# Epoch 19/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0092 - accuracy: 0.9977
# Epoch 20/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0086 - accuracy: 0.9977
# Epoch 21/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0075 - accuracy: 0.9977
# Epoch 22/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0063 - accuracy: 0.9983
# Epoch 23/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0066 - accuracy: 0.9983
# Epoch 24/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0061 - accuracy: 0.9983
# Epoch 25/50
# 875/875 [==============================] - 4s 4ms/step - loss: 0.0054 - accuracy: 0.9989
# Epoch 26/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0053 - accuracy: 0.9989
# Epoch 27/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0050 - accuracy: 0.9991
# Epoch 28/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0049 - accuracy: 0.9989
# Epoch 29/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0052 - accuracy: 0.9983
# Epoch 30/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0078 - accuracy: 0.9980
# Epoch 31/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0041 - accuracy: 0.9994
# Epoch 32/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0036 - accuracy: 0.9994
# Epoch 33/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0040 - accuracy: 0.9991
# Epoch 34/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0037 - accuracy: 0.9994
# Epoch 35/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0041 - accuracy: 0.9991
# Epoch 36/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0041 - accuracy: 0.9991
# Epoch 37/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0035 - accuracy: 0.9994
# Epoch 38/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0033 - accuracy: 0.9994
# Epoch 39/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0033 - accuracy: 0.9994
# Epoch 40/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0035 - accuracy: 0.9994
# Epoch 41/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0031 - accuracy: 0.9994
# Epoch 42/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0032 - accuracy: 0.9994
# Epoch 43/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0031 - accuracy: 0.9994
# Epoch 44/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0029 - accuracy: 0.9991
# Epoch 45/50
# 875/875 [==============================] - 3s 4ms/step - loss: 0.0028 - accuracy: 0.9994
# Epoch 46/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0029 - accuracy: 0.9994
# Epoch 47/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0025 - accuracy: 0.9994
# Epoch 48/50
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 49/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 50/50
# 875/875 [==============================] - 3s 3ms/step - loss: 0.0027 - accuracy: 0.9994

# %%
result = model.evaluate(X_test, y_test, verbose=1)
# Out:
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 0.9887

# %%
accuracy = result[1]
accuracy
# Out:
# 0.9886666536331177
